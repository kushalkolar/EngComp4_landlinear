# %%
import numpy
# %matplotlib inline
from matplotlib import pyplot

# %%
from urllib.request import urlretrieve
URL = 'https://go.gwu.edu/engcomp4plot'
urlretrieve(URL, 'plot_helper.py')
# Out:
# ('plot_helper.py', <http.client.HTTPMessage at 0x7f3050017cd0>)

# %%
from plot_helper import *

# %%
vectors = [(4, 10)]
tails = [(-1, 3), (-3, -1), (0, 0), (1, -3)]

# %%
plot_vector(vectors, tails)

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
a = np.array([-2, 1])
b = np.array([1, -3])

# %%
origin = np.array([0, 0])

# %%
vectors = [a, b, a+b]
tails = [origin, a, origin]

# %%
plot_vector(vectors, tails)

# %%
c = np.array([2, 1])
vectors = [c, 3*c]
plot_vector(vectors)

# %%
i = np.array([1, 0])
j = np.array([0, 1])

vec = 3*i + 2*j

vectors = [i, j, 3*i, 2*j, vec]

plot_vector(vectors)

# %%
xs = np.random.randint(-10, 10, 50)
ys = np.random.randint(-10, 10, 50)
plot_vector([x*i + y*j for x, y in zip(xs, ys)])

# %%
xs = np.random.randint(-10, 10, 500)
ys = np.random.randint(-10, 10, 500)
plot_vector([x*i + y*j for x, y in zip(xs, ys)])

# %%
a = np.array([2, 1])
b = np.array([-5, 3])
plot_vector([a, b, a+b])

# %%
xs = np.random.randint(-10, 10, 500)
ys = np.random.randint(-10, 10, 500)
plot_vector([x*a + y*b for x, y in zip(xs, ys)])

# %%
a = np.array([2, -1])
d = np.array([-1, 0.5])
plot_vector([a, d])

xs = np.random.randint(-10, 10, 30)
ys = np.random.randint(-10, 10, 30)
plot_vector([x*a + y*d for x, y in zip(xs, ys)])

# %%
a
# Out:
# array([ 2, -1])

# %%
b
# Out:
# array([-5,  3])

# %%
(a[0] * b[0]) + (a[1] * b[1])
# Out:
# -13

# %%
np.dot(a, b)
# Out:
# -13

# %%
np.linalg.norm(a)
# Out:
# 2.23606797749979

# %%
np.sqrt((a[0] * a[0]) + (a[1] * a[1]))
# Out:
# 2.23606797749979

# %%
np.sqrt(np.dot(a, a))
# Out:
# 2.23606797749979

# %%
cosine_distance = lambda p, q: 1 - (np.dot(p, q) / (np.linalg.norm(p) * np.linalg.norm(q)))

# %%
cosine_distance(a, b)
# Out:
# 1.9970544855015815

# %%
from scipy.spatial import distance

# %%
distance.cosine(a, b)
# Out:
# 1.9970544855015815

# %%
distance.cosine(a, d)
# Out:
# 2.0

# %%
(np.dot(a, d) / (np.linalg.norm(a) * np.linalg.norm(d)))
# Out:
# -0.9999999999999998
